# %%
# Import and read the data
import pandas as pd
import numpy as np
df = pd.read_csv('fake_jobs.csv',low_memory=False)

# %%
df.shape
# Out:
# (17880, 18)

# %%
# Print the % of empty cells in the data
# Top offenders (>40%) are: Salary range, Department, Benefits, required_experience, required_education...
# We decide to drop department, salary_range and benefits and try to repair the rest
# Loi : Localisation, titre du poste, fiche de poste
print("Missing values distribution: ")
print(df.isnull().mean())
# Out:
# Missing values distribution:
# job_id                 0.000000
# title                  0.000000
# location               0.019351
# department             0.645805
# salary_range           0.839597
# company_profile        0.185011
# description            0.000056
# requirements           0.150727
# benefits               0.403244
# telecommuting          0.000000
# has_company_logo       0.000000
# has_questions          0.000000
# employment_type        0.194128
# required_experience    0.394295
# required_education     0.453300
# industry               0.274217
# function               0.361018
# fraudulent             0.000000
# dtype: float64

# %%
df.drop(['department','salary_range','benefits','company_profile'], axis = 1, inplace = True)

# %%
df.shape
#columns have been dropped
# Out:
# (17880, 14)

# %%
df.isnull().mean()
# Out:
# job_id                 0.000000
# title                  0.000000
# location               0.019351
# description            0.000056
# requirements           0.150727
# telecommuting          0.000000
# has_company_logo       0.000000
# has_questions          0.000000
# employment_type        0.194128
# required_experience    0.394295
# required_education     0.453300
# industry               0.274217
# function               0.361018
# fraudulent             0.000000
# dtype: float64

# %%
rows = df[(df['required_education'].isnull()==True) & (df['required_experience'].isnull()==True) & (df['function'].isnull()==True)]
rows.shape
# Out:
# (4587, 14)

# %%
drop_rows = list(rows.index)
df_clean = df.drop(drop_rows, axis=0) #rows

# %%
df_clean.shape
# Out:
# (13293, 14)

# %%
df_clean.isnull().mean()
# Out:
# job_id                 0.000000
# title                  0.000000
# location               0.008125
# description            0.000000
# requirements           0.077560
# telecommuting          0.000000
# has_company_logo       0.000000
# has_questions          0.000000
# employment_type        0.043858
# required_experience    0.185285
# required_education     0.264651
# industry               0.093508
# function               0.140525
# fraudulent             0.000000
# dtype: float64

# %%
df_clean['required_experience'].value_counts()
# Out:
# Mid-Senior level    3809
# Entry level         2697
# Associate           2297
# Not Applicable      1116
# Director             389
# Internship           381
# Executive            141
# Name: required_experience, dtype: int64

# %%
df_clean.loc[df_clean['required_experience']=='Mid-Senior level']['required_education'].value_counts()
# Out:
# Bachelor's Degree                    1994
# Unspecified                           367
# Master's Degree                       158
# High School or equivalent             123
# Certification                          44
# Associate Degree                       43
# Professional                           30
# Vocational                             14
# Doctorate                              11
# Some College Coursework Completed       5
# Vocational - Degree                     3
# Some High School Coursework             1
# Vocational - HS Diploma                 1
# Name: required_education, dtype: int64

# %%
df_clean['required_experience'].unique()
# Out:
# array(['Internship', 'Not Applicable', 'Mid-Senior level', 'Associate',
#        'Entry level', 'Executive', nan, 'Director'], dtype=object)

# %%
lst = list(df_clean['required_experience'].unique())
lst.pop(6)
lst
# Out:
# ['Internship',
#  'Not Applicable',
#  'Mid-Senior level',
#  'Associate',
#  'Entry level',
#  'Executive',
#  'Director']

# %%
dic = dict(df_clean.loc[df_clean['required_experience']=='Mid-Senior level']['required_education'].value_counts())
dic
# Out:
# {"Bachelor's Degree": 1994,
#  'Unspecified': 367,
#  "Master's Degree": 158,
#  'High School or equivalent': 123,
#  'Certification': 44,
#  'Associate Degree': 43,
#  'Professional': 30,
#  'Vocational': 14,
#  'Doctorate': 11,
#  'Some College Coursework Completed': 5,
#  'Vocational - Degree': 3,
#  'Some High School Coursework': 1,
#  'Vocational - HS Diploma': 1}

# %%
list(dic.keys())[0]
# Out:
# "Bachelor's Degree"

# %%
for i in lst:
    dic = dict(df_clean.loc[df_clean['required_experience']==i]['required_education'].value_counts())
    print((i,list(dic.keys())[0]))
# Out:
# ('Internship', "Bachelor's Degree")
# ('Not Applicable', 'High School or equivalent')
# ('Mid-Senior level', "Bachelor's Degree")
# ('Associate', "Bachelor's Degree")
# ('Entry level', 'High School or equivalent')
# ('Executive', "Bachelor's Degree")
# ('Director', "Bachelor's Degree")

# %%
filter1 = (df_clean["required_experience"]=="Internship") & (df_clean['required_education'].isnull()==True)
filter2 = (df_clean["required_experience"]=='Not Applicable') & (df_clean['required_education'].isnull()==True)
filter3 = (df_clean["required_experience"]=='Mid-Senior level') & (df_clean['required_education'].isnull()==True)
filter4 = (df_clean["required_experience"]=='Associate') & (df_clean['required_education'].isnull()==True)
filter5 = (df_clean["required_experience"]=='Entry level') & (df_clean['required_education'].isnull()==True)
filter6 = (df_clean["required_experience"]=='Executive') & (df_clean['required_education'].isnull()==True)
filter7 = (df_clean["required_experience"]=='Director') & (df_clean['required_education'].isnull()==True)

# %%
df_clean[filter1].head()
# Out:
#       job_id                                              title  \
# 0          1                                   Marketing Intern
# 562      563                                  Production Intern
# 564      565  Wordpress Designer and Expert for Startup | St...
# 938      939                        Provisions eCommerce Intern
# 1020    1021                   Marketing Intern - Paid Position
#
#               location                                        description  \
# 0     US, NY, New York  Food52, a fast-growing, James Beard Award-winn...
# 562   US, NY, Brooklyn  Adventure Cow is looking for a production inte...
# 564             US, ,   #URL_ab309fb672a2b26317bd303c09c3c6762986d45c2...
# 938                NaN  Do you obsess over great products -- both styl...
# 1020   GB, LND, London  Fabrily is on the hunt for a brilliant marketi...
#
#                                            requirements  telecommuting  \
# 0     Experience with content management systems a m...              0
# 562                                                 NaN              0
# 564                                                 NaN              0
# 938   You may be a good fit for this position if you...              0
# 1020  * Self motivated, proactive, well organized an...              0
#
#       has_company_logo  has_questions employment_type required_experience  \
# 0                    1              0           Other          Internship
# 562                  0              0       Temporary          Internship
# 564                  1              0       Part-time          Internship
# 938                  1              1             NaN          Internship
# 1020                 1              1       Full-time          Internship
#
#      required_education  industry                function  fraudulent
# 0                   NaN       NaN               Marketing           0
# 562                 NaN       NaN              Production           0
# 564                 NaN       NaN  Information Technology           0
# 938                 NaN       NaN        General Business           0
# 1020                NaN  Internet                     NaN           0

# %%
df_clean['required_education'] = np.where(filter1,"Bachelor's Degree", df_clean['required_education'])
df_clean[filter1].head()
# Out:
#       job_id                                              title  \
# 0          1                                   Marketing Intern
# 562      563                                  Production Intern
# 564      565  Wordpress Designer and Expert for Startup | St...
# 938      939                        Provisions eCommerce Intern
# 1020    1021                   Marketing Intern - Paid Position
#
#               location                                        description  \
# 0     US, NY, New York  Food52, a fast-growing, James Beard Award-winn...
# 562   US, NY, Brooklyn  Adventure Cow is looking for a production inte...
# 564             US, ,   #URL_ab309fb672a2b26317bd303c09c3c6762986d45c2...
# 938                NaN  Do you obsess over great products -- both styl...
# 1020   GB, LND, London  Fabrily is on the hunt for a brilliant marketi...
#
#                                            requirements  telecommuting  \
# 0     Experience with content management systems a m...              0
# 562                                                 NaN              0
# 564                                                 NaN              0
# 938   You may be a good fit for this position if you...              0
# 1020  * Self motivated, proactive, well organized an...              0
#
#       has_company_logo  has_questions employment_type required_experience  \
# 0                    1              0           Other          Internship
# 562                  0              0       Temporary          Internship
# 564                  1              0       Part-time          Internship
# 938                  1              1             NaN          Internship
# 1020                 1              1       Full-time          Internship
#
#      required_education  industry                function  fraudulent
# 0     Bachelor's Degree       NaN               Marketing           0
# 562   Bachelor's Degree       NaN              Production           0
# 564   Bachelor's Degree       NaN  Information Technology           0
# 938   Bachelor's Degree       NaN        General Business           0
# 1020  Bachelor's Degree  Internet                     NaN           0

# %%
# ('Internship', "Bachelor's Degree")
# ('Not Applicable', 'High School or equivalent')
# ('Mid-Senior level', "Bachelor's Degree")
# ('Associate', "Bachelor's Degree")
# ('Entry level', 'High School or equivalent')
# ('Executive', "Bachelor's Degree")
# ('Director', "Bachelor's Degree")
df_clean['required_education'] = np.where(filter2,'High School or equivalent', df_clean['required_education'])
df_clean['required_education'] = np.where(filter3,"Bachelor's Degree", df_clean['required_education'])
df_clean['required_education'] = np.where(filter4,"Bachelor's Degree", df_clean['required_education'])
df_clean['required_education'] = np.where(filter5,'High School or equivalent', df_clean['required_education'])
df_clean['required_education'] = np.where(filter6,"Bachelor's Degree", df_clean['required_education'])
df_clean['required_education'] = np.where(filter7,"Bachelor's Degree", df_clean['required_education'])

# %%
df_clean.isnull().mean()
# Out:
# job_id                 0.000000
# title                  0.000000
# location               0.008125
# description            0.000000
# requirements           0.077560
# telecommuting          0.000000
# has_company_logo       0.000000
# has_questions          0.000000
# employment_type        0.043858
# required_experience    0.185285
# required_education     0.090198
# industry               0.093508
# function               0.140525
# fraudulent             0.000000
# dtype: float64

# %%
lst2 = list(df_clean['required_education'].unique())
lst2.pop(4)
lst2
# Out:
# ["Bachelor's Degree",
#  'High School or equivalent',
#  "Master's Degree",
#  'Unspecified',
#  'Some College Coursework Completed',
#  'Vocational',
#  'Certification',
#  'Associate Degree',
#  'Professional',
#  'Doctorate',
#  'Some High School Coursework',
#  'Vocational - Degree',
#  'Vocational - HS Diploma']

# %%
dic2 = dict(df_clean.loc[df_clean['required_education']=='High School or equivalent']['required_experience'].value_counts())
dic2
# Out:
# {'Entry level': 1549,
#  'Not Applicable': 590,
#  'Associate': 243,
#  'Mid-Senior level': 123,
#  'Internship': 39,
#  'Director': 2,
#  'Executive': 1}

# %%
for i in lst2:
    dic2 = dict(df_clean.loc[df_clean['required_education']==i]['required_experience'].value_counts())
    print((i,list(dic2.keys())[0]))
# Out:
# ("Bachelor's Degree", 'Mid-Senior level')
# ('High School or equivalent', 'Entry level')
# ("Master's Degree", 'Mid-Senior level')
# ('Unspecified', 'Mid-Senior level')
# ('Some College Coursework Completed', 'Internship')
# ('Vocational', 'Associate')
# ('Certification', 'Mid-Senior level')
# ('Associate Degree', 'Associate')
# ('Professional', 'Mid-Senior level')
# ('Doctorate', 'Mid-Senior level')
# ('Some High School Coursework', 'Entry level')
# ('Vocational - Degree', 'Mid-Senior level')
# ('Vocational - HS Diploma', 'Entry level')

# %%
filt1 = (df_clean["required_education"]=="Bachelor's Degree") & (df_clean['required_experience'].isnull()==True)
filt2 = (df_clean["required_education"]=='High School or equivalent') & (df_clean['required_experience'].isnull()==True)
filt3 = (df_clean["required_education"]=="Master's Degree") & (df_clean['required_experience'].isnull()==True)
filt4 = (df_clean["required_education"]=='Unspecified') & (df_clean['required_experience'].isnull()==True)
filt5 = (df_clean["required_education"]=='Some College Coursework Completed') & (df_clean['required_experience'].isnull()==True)
filt6 = (df_clean["required_education"]=='Vocational') & (df_clean['required_experience'].isnull()==True)
filt7 = (df_clean["required_education"]=='Certification') & (df_clean['required_experience'].isnull()==True)
filt8 = (df_clean["required_education"]=='Associate Degree') & (df_clean['required_experience'].isnull()==True)
filt9 = (df_clean["required_education"]=='Professional') & (df_clean['required_experience'].isnull()==True)
filt10 = (df_clean["required_education"]=='Doctorate') & (df_clean['required_experience'].isnull()==True)
filt11 = (df_clean["required_education"]=='Some High School Coursework') & (df_clean['required_experience'].isnull()==True)
filt12 = (df_clean["required_education"]=='Vocational - Degree') & (df_clean['required_experience'].isnull()==True)
filt13 = (df_clean["required_education"]=='Vocational - HS Diploma') & (df_clean['required_experience'].isnull()==True)

# %%
("Bachelor's Degree", 'Mid-Senior level')
('High School or equivalent', 'Entry level')
("Master's Degree", 'Mid-Senior level')
('Unspecified', 'Mid-Senior level')
('Some College Coursework Completed', 'Internship')
('Vocational', 'Associate')
('Certification', 'Mid-Senior level')
('Associate Degree', 'Associate')
('Professional', 'Mid-Senior level')
('Doctorate', 'Mid-Senior level')
('Some High School Coursework', 'Entry level')
('Vocational - Degree', 'Mid-Senior level')
('Vocational - HS Diploma', 'Entry level')
# Out:
# ('Vocational - HS Diploma', 'Entry level')

# %%
df_clean['required_experience'] = np.where(filt1,'Mid-Senior level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt2,'Entry level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt3,'Mid-Senior level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt4,'Mid-Senior level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt5,'Internship', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt6,'Associate', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt7,'Mid-Senior level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt8,'Associate', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt9,'Mid-Senior level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt10,'Mid-Senior level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt11,'Entry level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt12,'Mid-Senior level', df_clean['required_experience'])
df_clean['required_experience'] = np.where(filt13,'Entry level', df_clean['required_experience'])

# %%
df_clean[filter1].head()
# Out:
#       job_id                                              title  \
# 0          1                                   Marketing Intern
# 562      563                                  Production Intern
# 564      565  Wordpress Designer and Expert for Startup | St...
# 938      939                        Provisions eCommerce Intern
# 1020    1021                   Marketing Intern - Paid Position
#
#               location                                        description  \
# 0     US, NY, New York  Food52, a fast-growing, James Beard Award-winn...
# 562   US, NY, Brooklyn  Adventure Cow is looking for a production inte...
# 564             US, ,   #URL_ab309fb672a2b26317bd303c09c3c6762986d45c2...
# 938                NaN  Do you obsess over great products -- both styl...
# 1020   GB, LND, London  Fabrily is on the hunt for a brilliant marketi...
#
#                                            requirements  telecommuting  \
# 0     Experience with content management systems a m...              0
# 562                                                 NaN              0
# 564                                                 NaN              0
# 938   You may be a good fit for this position if you...              0
# 1020  * Self motivated, proactive, well organized an...              0
#
#       has_company_logo  has_questions employment_type required_experience  \
# 0                    1              0           Other          Internship
# 562                  0              0       Temporary          Internship
# 564                  1              0       Part-time          Internship
# 938                  1              1             NaN          Internship
# 1020                 1              1       Full-time          Internship
#
#      required_education  industry                function  fraudulent
# 0     Bachelor's Degree       NaN               Marketing           0
# 562   Bachelor's Degree       NaN              Production           0
# 564   Bachelor's Degree       NaN  Information Technology           0
# 938   Bachelor's Degree       NaN        General Business           0
# 1020  Bachelor's Degree  Internet                     NaN           0

# %%
df_clean.isnull().mean()
# Out:
# job_id                 0.000000
# title                  0.000000
# location               0.008125
# description            0.000000
# requirements           0.077560
# telecommuting          0.000000
# has_company_logo       0.000000
# has_questions          0.000000
# employment_type        0.043858
# required_experience    0.090198
# required_education     0.090198
# industry               0.093508
# function               0.140525
# fraudulent             0.000000
# dtype: float64

# %%
teacher = (df_clean['title'].str.contains(r'Teacher')) & (df_clean['function'].isnull()==True)  #Education
cs = (df_clean['title'].str.contains(r'Customer Service')) & (df_clean['function'].isnull()==True) #Customer Service 
dev = (df_clean['title'].str.contains(r'Developer')) & (df_clean['function'].isnull()==True) #Engineering 
eng = (df_clean['title'].str.contains(r'Engineer')) & (df_clean['function'].isnull()==True)#Engineering  
science = (df_clean['title'].str.contains(r'Data Scientist'))  & (df_clean['function'].isnull()==True)#Science  
design = (df_clean['title'].str.contains(r'Design')) & (df_clean['function'].isnull()==True) #Design  
sales = (df_clean['title'].str.contains(r'Sales')) & (df_clean['function'].isnull()==True) #Sales  
mark = (df_clean['title'].str.contains(r'Marketing')) & (df_clean['function'].isnull()==True) #Marketing 
am = (df_clean['title'].str.contains(r'Account Manager')) & (df_clean['function'].isnull()==True) #Sales 
ae = (df_clean['title'].str.contains(r'Account Executive')) & (df_clean['function'].isnull()==True)#Sales 
acc = (df_clean['title'].str.contains(r'Accountant')) & (df_clean['function'].isnull()==True)#Finance

# %%
df_clean['function'] = np.where(teacher,'Education', df_clean['function'])
df_clean['function'] = np.where(cs,'Customer Service', df_clean['function'])
df_clean['function'] = np.where(dev,'Engineering', df_clean['function'])
df_clean['function'] = np.where(eng,'Engineering', df_clean['function'])
df_clean['function'] = np.where(science,'Science', df_clean['function'])
df_clean['function'] = np.where(design,'Design', df_clean['function'])
df_clean['function'] = np.where(sales,'Sales', df_clean['function'])
df_clean['function'] = np.where(mark,'Marketing', df_clean['function'])
df_clean['function'] = np.where(am,'Sales', df_clean['function'])
df_clean['function'] = np.where(ae,'Sales', df_clean['function'])
df_clean['function'] = np.where(acc,'Finance', df_clean['function'])

# %%
df_clean.isnull().mean()
# Out:
# job_id                 0.000000
# title                  0.000000
# location               0.008125
# description            0.000000
# requirements           0.077560
# telecommuting          0.000000
# has_company_logo       0.000000
# has_questions          0.000000
# employment_type        0.043858
# required_experience    0.090198
# required_education     0.090198
# industry               0.093508
# function               0.070413
# fraudulent             0.000000
# dtype: float64

# %%
df_clean.to_csv("data_clean.csv")

# %%
df_clean.head(25)
# Out:
#     job_id                                              title  \
# 0        1                                   Marketing Intern
# 1        2          Customer Service - Cloud Video Production
# 3        4                  Account Executive - Washington DC
# 4        5                                Bill Review Manager
# 6        7                              Head of Content (m/f)
# 8        9                                         HP BSM SME
# 9       10            Customer Service Associate - Part Time
# 10      11  ASP.net Developer Job opportunity at United St...
# 12      13                   Applications Developer, Digital
# 13      14                                         Installers
# 14      15                         Account Executive - Sydney
# 15      16                         VP of Sales - Vault Dragon
# 16      17                                Hands-On QA Leader
# 20      21                                Marketing Assistant
# 21      22                             Front End Developer
# 22      23                                Engagement Manager
# 23      24  Vice President, Sales and Sponsorship (Busines...
# 26      27                                     Marketing Exec
# 27      28           HAAD/DHA Licensed Doctors Opening in UAE
# 29      30                        Customer Service Associate
# 30      31             Customer Service Technical Specialist
# 31      32                   Software Applications Specialist
# 32      33                                Craftsman Associate
# 33      34                                Completion Engineer
# 35      36                            English Teacher Abroad
#
#                      location  \
# 0            US, NY, New York
# 1              NZ, , Auckland
# 3          US, DC, Washington
# 4          US, FL, Fort Worth
# 6              DE, BE, Berlin
# 8           US, FL, Pensacola
# 9             US, AZ, Phoenix
# 10        US, NJ, Jersey City
# 12           US, CT, Stamford
# 13            US, FL, Orlando
# 14            AU, NSW, Sydney
# 15          SG, 01, Singapore
# 16     IL, , Tel Aviv, Israel
# 20             US, TX, Austin
# 21            NZ, N, Auckland
# 22                     AE, ,
# 23           US, CA, Carlsbad
# 26                     SG, ,
# 27           AE, AZ, Abudhabi
# 29            CA, ON, Toronto
# 30            US, MA, Waltham
# 31                   US, KS,
# 32            US, WA, Everett
# 33          US, CA, San Ramon
# 35  US, NY, Saint Bonaventure
#
#                                           description  \
# 0   Food52, a fast-growing, James Beard Award-winn...
# 1   Organised - Focused - Vibrant - Awesome!Do you...
# 3   THE COMPANY: ESRI – Environmental Systems Rese...
# 4   JOB TITLE: Itemization Review ManagerLOCATION:...
# 6   Your Responsibilities: Manage the English-spea...
# 8   Implementation/Configuration/Testing/Training ...
# 9   The Customer Service Associate will be based i...
# 10  Position : #URL_86fd830a95a64e2b30ceed829e63fd...
# 12  The Applications Developer, Digital will devel...
# 13  Event Industry Installers Needed!! (Orlando, F...
# 14  Are you interested in a satisfying and financi...
# 15  About Vault Dragon Vault Dragon is Dropbox for...
# 16  We are looking for a Hands-On QA Leader for ou...
# 20  IntelliBright is growing fast and is looking f...
# 21  Want to be part of a globally focused tech tea...
# 22  The position reports to the Head of Engagement...
# 23  #URL_eda2500ddcedb60957fcd7f5b164e092966f8c4e8...
# 26  We are currently expanding our Marketing Depar...
# 27  HAAD/DHA Licensed Doctors Opening in UAEWe the...
# 29  The Customer Service Associate will be based i...
# 30  The Customer Service Technical Specialist will...
# 31  Day to Day-Install, upgrade and configure web-...
# 32  Construction: Entry-Level Craftsman Associate ...
# 33  About the CompanyThis is an amazing job opport...
# 35  Play with kids, get paid for it Love travel? J...
#
#                                          requirements  telecommuting  \
# 0   Experience with content management systems a m...              0
# 1   What we expect from you:Your key responsibilit...              0
# 3   EDUCATION: Bachelor’s or Master’s in GIS, busi...              0
# 4   QUALIFICATIONS:RN license in the State of Texa...              0
# 6   Your Know-How:                                ...              0
# 8   MUST BE A US CITIZEN.An active TS/SCI clearanc...              0
# 9   Minimum Requirements:Minimum of 6 months custo...              0
# 10  Position : #URL_86fd830a95a64e2b30ceed829e63fd...              0
# 12  Requirements:4 – 5 years’ experience in develo...              0
# 13  Valid driver's license,Somewhat Clean driving ...              0
# 14  You’ll need to be smart and passionate and hav...              0
# 15  Key Superpowers3-5 years of high-pressure sale...              0
# 16  Previous experience in client &amp; server tes...              0
# 20  Job RequirementsAssist in creating client onli...              0
# 21  You will most likely have:A solid mastery of m...              0
# 22  RequirementsThe ideal candidate will be bright...              0
# 23  Job Requirements:A reputation as a "go-getter"...              0
# 26  This position is Junior to Mid level. Ideally,...              0
# 27  RequirementsEndocrinologistGastroenterologistC...              0
# 29  Minimum Requirements:Minimum of 1 year custome...              0
# 30  Qualifications:Minimum of 6 months customer se...              0
# 31  Must Have's3+ years of experience with web-bas...              0
# 32  Requirements:  (Please do not apply if you do ...              0
# 33  Education:Bachelor of Science in Petroleum Eng...              0
# 35  University degree required. TEFL / TESOL / CEL...              0
#
#     has_company_logo  has_questions employment_type required_experience  \
# 0                  1              0           Other          Internship
# 1                  1              0       Full-time      Not Applicable
# 3                  1              0       Full-time    Mid-Senior level
# 4                  1              1       Full-time    Mid-Senior level
# 6                  1              1       Full-time    Mid-Senior level
# 8                  1              1       Full-time           Associate
# 9                  1              0       Part-time         Entry level
# 10                 0              0       Full-time    Mid-Senior level
# 12                 1              0       Full-time           Associate
# 13                 1              1       Full-time      Not Applicable
# 14                 1              0       Full-time           Associate
# 15                 1              1       Full-time           Executive
# 16                 1              0       Full-time    Mid-Senior level
# 20                 1              0             NaN                 NaN
# 21                 1              0       Full-time    Mid-Senior level
# 22                 1              1       Full-time    Mid-Senior level
# 23                 1              0       Full-time           Executive
# 26                 1              0       Full-time           Associate
# 27                 1              0       Full-time           Associate
# 29                 1              0       Full-time         Entry level
# 30                 1              0       Full-time         Entry level
# 31                 1              0       Full-time           Associate
# 32                 1              1       Full-time         Entry level
# 33                 1              1       Full-time    Mid-Senior level
# 35                 1              1        Contract    Mid-Senior level
#
#            required_education                             industry  \
# 0           Bachelor's Degree                                  NaN
# 1   High School or equivalent            Marketing and Advertising
# 3           Bachelor's Degree                    Computer Software
# 4           Bachelor's Degree               Hospital & Health Care
# 6             Master's Degree                         Online Media
# 8           Bachelor's Degree  Information Technology and Services
# 9   High School or equivalent                   Financial Services
# 10          Bachelor's Degree  Information Technology and Services
# 12          Bachelor's Degree                Management Consulting
# 13                Unspecified                      Events Services
# 14          Bachelor's Degree                             Internet
# 15          Bachelor's Degree                  Facilities Services
# 16          Bachelor's Degree                             Internet
# 20                        NaN                                  NaN
# 21            Master's Degree                 Consumer Electronics
# 22          Bachelor's Degree                   Telecommunications
# 23                Unspecified                             Internet
# 26          Bachelor's Degree                         Online Media
# 27            Master's Degree               Hospital & Health Care
# 29  High School or equivalent                    Consumer Services
# 30  High School or equivalent                    Computer Software
# 31                Unspecified                    Computer Software
# 32                Unspecified                         Construction
# 33          Bachelor's Degree                         Oil & Energy
# 35          Bachelor's Degree                 Education Management
#
#                   function  fraudulent
# 0                Marketing           0
# 1         Customer Service           0
# 3                    Sales           0
# 4     Health Care Provider           0
# 6               Management           0
# 8                      NaN           0
# 9         Customer Service           0
# 10  Information Technology           0
# 12  Information Technology           0
# 13                   Other           0
# 14                   Sales           0
# 15                   Sales           0
# 16             Engineering           0
# 20               Marketing           0
# 21             Engineering           0
# 22                   Sales           0
# 23                   Sales           0
# 26               Marketing           0
# 27    Health Care Provider           0
# 29          Administrative           0
# 30        Customer Service           0
# 31             Engineering           0
# 32                   Other           0
# 33             Engineering           0
# 35               Education           0
